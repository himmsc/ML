# %% [markdown]
# # **Машинное обучение РК-1**

# %% [markdown]
# ### **Баканов Сергей ИБМ3-65Б**

# %% [markdown]
# Библиотеки.

# %%
import sklearn as skl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Чтение датасета.

# %%
data = skl.datasets.load_iris()
y = data['target']
df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()

# %% [markdown]
# Добавление species в датафрейм.

# %%
df_with_target = df.copy()
df_with_target['species'] = y

# %% [markdown]
# ### 1. Пропуски

# %%
df.isna().sum()

# %% [markdown]
# ![Пропуски](ML_RK/Empty.png)

# %% [markdown]
# ### 2. Корреляционная матрица

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df_with_target.corr(), annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Корреляционная матрица (признаки + target)')
plt.show()

# %% [markdown]
# ![](ML_RK/corrm1.png)

# %% [markdown]
# ### 3. Влияние признаков на целевую переменную (species)
#
#
# | Признак | Корреляция с species |
# | :--- | :---: |
# | **petal width (cm)** | 0.96 |
# | **petal length (cm)** | 0.95 |
# | **sepal length (cm)** | 0.78 |
# | **sepal width (cm)** | -0.43 |

# %% [markdown]
# Самые важные признаки - petal width и petal length. Высокая прямая связь.
# Sepal length - тоже высокая прямая связь с species.
# Sepal width - средняя обратная связь в таргетом.

# %% [markdown]
# ### 4. Гистограмма

# %%
# Группируем по видам и считаем средние значения
df_with_target = df.copy()
df_with_target['species'] = y

# Средние значения признаков для каждого вида
mean_by_species = df_with_target.groupby('species').mean()

# Строим гистограмму
mean_by_species.T.plot(kind='bar', figsize=(10, 6))
plt.title('Средние значения признаков по видам ирисов')
plt.xlabel('Признаки')
plt.ylabel('Среднее значение (см)')
plt.legend(title='Вид', labels=['Setosa', 'Versicolor', 'Virginica'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ![Пропуски](ML_RK/hist.png)

# %% [markdown]
# ## Анализ
# 1. В Датафрейме нет пропусков.
# 2. Все признаки числовые.
# 3. Целевая переменная число от 0 до 2.
# Вывод: Можно приступать к создании ML - модели.
